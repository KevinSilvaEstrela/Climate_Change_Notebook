# %% [markdown]
# ## **Etapa 1 - Seleção:**
#
# Para fazer a seleção dos dados é preciso importar a biblioteca "Pandas" e dar o apelido "PD" para facilitar seu uso. Depois é criada uma variável para receber os dados, nesse caso vamos chama-lá de df(Dataframe), podendo ser qualquer nome. Em seguida utilizamos o método "read_cvs" para ler o arquivo. Este método é usado para arquivos CSV(Comma Separeted Values - Valores separados por vírgula), mas existem métodos para diversos formatos de arquivo, como excel, sql, tsv, etc...

# %%
import pandas as pd

df = pd.read_csv("/content/climate_change_indicators.csv")

# Printando o DataFrame
df
# Out:
#      ObjectId                       Country ISO2 ISO3  \
# 0           1  Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                       Albania   AL  ALB
# 2           3                       Algeria   DZ  DZA
# 3           4                American Samoa   AS  ASM
# 4           5      Andorra, Principality of   AD  AND
# ..        ...                           ...  ...  ...
# 220       221                Western Sahara   EH  ESH
# 221       222                         World  NaN  WLD
# 222       223                Yemen, Rep. of   YE  YEM
# 223       224                        Zambia   ZM  ZMB
# 224       225                      Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 0    Temperature change with respect to a baseline ...  Degree Celsius
# 1    Temperature change with respect to a baseline ...  Degree Celsius
# 2    Temperature change with respect to a baseline ...  Degree Celsius
# 3    Temperature change with respect to a baseline ...  Degree Celsius
# 4    Temperature change with respect to a baseline ...  Degree Celsius
# ..                                                 ...             ...
# 220  Temperature change with respect to a baseline ...  Degree Celsius
# 221  Temperature change with respect to a baseline ...  Degree Celsius
# 222  Temperature change with respect to a baseline ...  Degree Celsius
# 223  Temperature change with respect to a baseline ...  Degree Celsius
# 224  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                                 Source CTS_Code  \
# 0    Food and Agriculture Organization of the Unite...     ECCS
# 1    Food and Agriculture Organization of the Unite...     ECCS
# 2    Food and Agriculture Organization of the Unite...     ECCS
# 3    Food and Agriculture Organization of the Unite...     ECCS
# 4    Food and Agriculture Organization of the Unite...     ECCS
# ..                                                 ...      ...
# 220  Food and Agriculture Organization of the Unite...     ECCS
# 221  Food and Agriculture Organization of the Unite...     ECCS
# 222  Food and Agriculture Organization of the Unite...     ECCS
# 223  Food and Agriculture Organization of the Unite...     ECCS
# 224  Food and Agriculture Organization of the Unite...     ECCS
#
#                        CTS_Name  \
# 0    Surface Temperature Change
# 1    Surface Temperature Change
# 2    Surface Temperature Change
# 3    Surface Temperature Change
# 4    Surface Temperature Change
# ..                          ...
# 220  Surface Temperature Change
# 221  Surface Temperature Change
# 222  Surface Temperature Change
# 223  Surface Temperature Change
# 224  Surface Temperature Change
#
#                                    CTS_Full_Descriptor  ...  F2013  F2014  \
# 0    Environment, Climate Change, Climate Indicator...  ...  1.281  0.456
# 1    Environment, Climate Change, Climate Indicator...  ...  1.333  1.198
# 2    Environment, Climate Change, Climate Indicator...  ...  1.192  1.690
# 3    Environment, Climate Change, Climate Indicator...  ...  1.257  1.170
# 4    Environment, Climate Change, Climate Indicator...  ...  0.831  1.946
# ..                                                 ...  ...    ...    ...
# 220  Environment, Climate Change, Climate Indicator...  ...  1.423  1.401
# 221  Environment, Climate Change, Climate Indicator...  ...  1.016  1.053
# 222  Environment, Climate Change, Climate Indicator...  ...    NaN    NaN
# 223  Environment, Climate Change, Climate Indicator...  ...  0.790  0.917
# 224  Environment, Climate Change, Climate Indicator...  ...  0.118  0.025
#
#      F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 0    1.093  1.555  1.540  1.544  0.910  0.498  1.327  2.012
# 1    1.569  1.464  1.121  2.028  1.675  1.498  1.536  1.518
# 2    1.121  1.757  1.512  1.210  1.115  1.926  2.330  1.688
# 3    1.009  1.539  1.435  1.189  1.539  1.430  1.268  1.256
# 4    1.690  1.990  1.925  1.919  1.964  2.562  1.533  3.243
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 220  1.510  1.732  2.204  0.942  1.477  2.069  1.593  1.970
# 221  1.412  1.660  1.429  1.290  1.444  1.711  1.447  1.394
# 222    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 223  1.450  1.401  0.105  0.648  0.855  0.891  0.822  0.686
# 224  0.970  1.270  0.088  0.453  0.925  0.389 -0.125 -0.490
#
# [225 rows x 72 columns]

# %%
# Usamos o método "head" para listar as 5 primeiras linhas do DataFrame.
df.head()
# Out:
#    ObjectId                       Country ISO2 ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF  AFG
# 1         2                       Albania   AL  ALB
# 2         3                       Algeria   DZ  DZA
# 3         4                American Samoa   AS  ASM
# 4         5      Andorra, Principality of   AD  AND
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
# 3  Temperature change with respect to a baseline ...  Degree Celsius
# 4  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS_Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# 2  Food and Agriculture Organization of the Unite...     ECCS
# 3  Food and Agriculture Organization of the Unite...     ECCS
# 4  Food and Agriculture Organization of the Unite...     ECCS
#
#                      CTS_Name  \
# 0  Surface Temperature Change
# 1  Surface Temperature Change
# 2  Surface Temperature Change
# 3  Surface Temperature Change
# 4  Surface Temperature Change
#
#                                  CTS_Full_Descriptor  ...  F2013  F2014  \
# 0  Environment, Climate Change, Climate Indicator...  ...  1.281  0.456
# 1  Environment, Climate Change, Climate Indicator...  ...  1.333  1.198
# 2  Environment, Climate Change, Climate Indicator...  ...  1.192  1.690
# 3  Environment, Climate Change, Climate Indicator...  ...  1.257  1.170
# 4  Environment, Climate Change, Climate Indicator...  ...  0.831  1.946
#
#    F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 0  1.093  1.555  1.540  1.544  0.910  0.498  1.327  2.012
# 1  1.569  1.464  1.121  2.028  1.675  1.498  1.536  1.518
# 2  1.121  1.757  1.512  1.210  1.115  1.926  2.330  1.688
# 3  1.009  1.539  1.435  1.189  1.539  1.430  1.268  1.256
# 4  1.690  1.990  1.925  1.919  1.964  2.562  1.533  3.243
#
# [5 rows x 72 columns]

# %%
df.tail()
# Out:
#      ObjectId         Country ISO2 ISO3  \
# 220       221  Western Sahara   EH  ESH
# 221       222           World  NaN  WLD
# 222       223  Yemen, Rep. of   YE  YEM
# 223       224          Zambia   ZM  ZMB
# 224       225        Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 220  Temperature change with respect to a baseline ...  Degree Celsius
# 221  Temperature change with respect to a baseline ...  Degree Celsius
# 222  Temperature change with respect to a baseline ...  Degree Celsius
# 223  Temperature change with respect to a baseline ...  Degree Celsius
# 224  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                                 Source CTS_Code  \
# 220  Food and Agriculture Organization of the Unite...     ECCS
# 221  Food and Agriculture Organization of the Unite...     ECCS
# 222  Food and Agriculture Organization of the Unite...     ECCS
# 223  Food and Agriculture Organization of the Unite...     ECCS
# 224  Food and Agriculture Organization of the Unite...     ECCS
#
#                        CTS_Name  \
# 220  Surface Temperature Change
# 221  Surface Temperature Change
# 222  Surface Temperature Change
# 223  Surface Temperature Change
# 224  Surface Temperature Change
#
#                                    CTS_Full_Descriptor  ...  F2013  F2014  \
# 220  Environment, Climate Change, Climate Indicator...  ...  1.423  1.401
# 221  Environment, Climate Change, Climate Indicator...  ...  1.016  1.053
# 222  Environment, Climate Change, Climate Indicator...  ...    NaN    NaN
# 223  Environment, Climate Change, Climate Indicator...  ...  0.790  0.917
# 224  Environment, Climate Change, Climate Indicator...  ...  0.118  0.025
#
#      F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 220  1.510  1.732  2.204  0.942  1.477  2.069  1.593  1.970
# 221  1.412  1.660  1.429  1.290  1.444  1.711  1.447  1.394
# 222    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 223  1.450  1.401  0.105  0.648  0.855  0.891  0.822  0.686
# 224  0.970  1.270  0.088  0.453  0.925  0.389 -0.125 -0.490
#
# [5 rows x 72 columns]

# %% [markdown]
# ## Etapa 2 - Pré-processamento:
#
# É possível observar que existem linhas com valores nulos, mas para ter certeza da quantidade e se vai afetar o DataFrame vamos usar a biblioteca "Missingno" para saber com precisão a quantidade de linhas nulas.

# %%
import missingno as msno

# Gerando uma matrix com os dados. Cada linha branca são os valores nulos
msno.matrix(df, figsize=(10, 8))
# Out:
# <Axes: >

# %%
# Dropna exclui as linhas com valores nulos. Adicionando o parametro 'Inplace = True' para modificar o dataframe original
df.dropna(inplace = True)

# %%
# Podemos ver que as linhas com valores nulos foram removidas
df
# Out:
#      ObjectId                       Country ISO2 ISO3  \
# 0           1  Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                       Albania   AL  ALB
# 2           3                       Algeria   DZ  DZA
# 4           5      Andorra, Principality of   AD  AND
# 5           6                        Angola   AO  AGO
# ..        ...                           ...  ...  ...
# 218       219     Wallis and Futuna Islands   WF  WLF
# 219       220            West Bank and Gaza   PS  PSE
# 220       221                Western Sahara   EH  ESH
# 223       224                        Zambia   ZM  ZMB
# 224       225                      Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 0    Temperature change with respect to a baseline ...  Degree Celsius
# 1    Temperature change with respect to a baseline ...  Degree Celsius
# 2    Temperature change with respect to a baseline ...  Degree Celsius
# 4    Temperature change with respect to a baseline ...  Degree Celsius
# 5    Temperature change with respect to a baseline ...  Degree Celsius
# ..                                                 ...             ...
# 218  Temperature change with respect to a baseline ...  Degree Celsius
# 219  Temperature change with respect to a baseline ...  Degree Celsius
# 220  Temperature change with respect to a baseline ...  Degree Celsius
# 223  Temperature change with respect to a baseline ...  Degree Celsius
# 224  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                                 Source CTS_Code  \
# 0    Food and Agriculture Organization of the Unite...     ECCS
# 1    Food and Agriculture Organization of the Unite...     ECCS
# 2    Food and Agriculture Organization of the Unite...     ECCS
# 4    Food and Agriculture Organization of the Unite...     ECCS
# 5    Food and Agriculture Organization of the Unite...     ECCS
# ..                                                 ...      ...
# 218  Food and Agriculture Organization of the Unite...     ECCS
# 219  Food and Agriculture Organization of the Unite...     ECCS
# 220  Food and Agriculture Organization of the Unite...     ECCS
# 223  Food and Agriculture Organization of the Unite...     ECCS
# 224  Food and Agriculture Organization of the Unite...     ECCS
#
#                        CTS_Name  \
# 0    Surface Temperature Change
# 1    Surface Temperature Change
# 2    Surface Temperature Change
# 4    Surface Temperature Change
# 5    Surface Temperature Change
# ..                          ...
# 218  Surface Temperature Change
# 219  Surface Temperature Change
# 220  Surface Temperature Change
# 223  Surface Temperature Change
# 224  Surface Temperature Change
#
#                                    CTS_Full_Descriptor  ...  F2013  F2014  \
# 0    Environment, Climate Change, Climate Indicator...  ...  1.281  0.456
# 1    Environment, Climate Change, Climate Indicator...  ...  1.333  1.198
# 2    Environment, Climate Change, Climate Indicator...  ...  1.192  1.690
# 4    Environment, Climate Change, Climate Indicator...  ...  0.831  1.946
# 5    Environment, Climate Change, Climate Indicator...  ...  1.044  0.828
# ..                                                 ...  ...    ...    ...
# 218  Environment, Climate Change, Climate Indicator...  ...  0.773  0.686
# 219  Environment, Climate Change, Climate Indicator...  ...  1.114  0.863
# 220  Environment, Climate Change, Climate Indicator...  ...  1.423  1.401
# 223  Environment, Climate Change, Climate Indicator...  ...  0.790  0.917
# 224  Environment, Climate Change, Climate Indicator...  ...  0.118  0.025
#
#      F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 0    1.093  1.555  1.540  1.544  0.910  0.498  1.327  2.012
# 1    1.569  1.464  1.121  2.028  1.675  1.498  1.536  1.518
# 2    1.121  1.757  1.512  1.210  1.115  1.926  2.330  1.688
# 4    1.690  1.990  1.925  1.919  1.964  2.562  1.533  3.243
# 5    1.331  1.609  0.870  1.395  1.752  1.162  1.553  1.212
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 218  0.724  1.267  1.062  0.920  1.379  1.274  1.029  0.951
# 219  1.326  1.615  0.735  2.007  1.204  1.455  1.787  1.074
# 220  1.510  1.732  2.204  0.942  1.477  2.069  1.593  1.970
# 223  1.450  1.401  0.105  0.648  0.855  0.891  0.822  0.686
# 224  0.970  1.270  0.088  0.453  0.925  0.389 -0.125 -0.490
#
# [156 rows x 72 columns]

# %% [markdown]
# ## Etapa 3 - Transformação:
#
# Após remover as linhas com valores vazios, podemos notar que o index numérico do dataframe não foi alterado, o que poderia causar problemas na hora de manipula-lo. Vamos então resetar o index para normalizar a manipulação do dataframe.

# %%
# Resetando o index original e modificando o dataframe
df.reset_index(drop = True, inplace = True)

# %%
# O index anterior foi descartado e foi gerado um novo
df
# Out:
#      ObjectId                       Country ISO2 ISO3  \
# 0           1  Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                       Albania   AL  ALB
# 2           3                       Algeria   DZ  DZA
# 3           5      Andorra, Principality of   AD  AND
# 4           6                        Angola   AO  AGO
# ..        ...                           ...  ...  ...
# 151       219     Wallis and Futuna Islands   WF  WLF
# 152       220            West Bank and Gaza   PS  PSE
# 153       221                Western Sahara   EH  ESH
# 154       224                        Zambia   ZM  ZMB
# 155       225                      Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 0    Temperature change with respect to a baseline ...  Degree Celsius
# 1    Temperature change with respect to a baseline ...  Degree Celsius
# 2    Temperature change with respect to a baseline ...  Degree Celsius
# 3    Temperature change with respect to a baseline ...  Degree Celsius
# 4    Temperature change with respect to a baseline ...  Degree Celsius
# ..                                                 ...             ...
# 151  Temperature change with respect to a baseline ...  Degree Celsius
# 152  Temperature change with respect to a baseline ...  Degree Celsius
# 153  Temperature change with respect to a baseline ...  Degree Celsius
# 154  Temperature change with respect to a baseline ...  Degree Celsius
# 155  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                                 Source CTS_Code  \
# 0    Food and Agriculture Organization of the Unite...     ECCS
# 1    Food and Agriculture Organization of the Unite...     ECCS
# 2    Food and Agriculture Organization of the Unite...     ECCS
# 3    Food and Agriculture Organization of the Unite...     ECCS
# 4    Food and Agriculture Organization of the Unite...     ECCS
# ..                                                 ...      ...
# 151  Food and Agriculture Organization of the Unite...     ECCS
# 152  Food and Agriculture Organization of the Unite...     ECCS
# 153  Food and Agriculture Organization of the Unite...     ECCS
# 154  Food and Agriculture Organization of the Unite...     ECCS
# 155  Food and Agriculture Organization of the Unite...     ECCS
#
#                        CTS_Name  \
# 0    Surface Temperature Change
# 1    Surface Temperature Change
# 2    Surface Temperature Change
# 3    Surface Temperature Change
# 4    Surface Temperature Change
# ..                          ...
# 151  Surface Temperature Change
# 152  Surface Temperature Change
# 153  Surface Temperature Change
# 154  Surface Temperature Change
# 155  Surface Temperature Change
#
#                                    CTS_Full_Descriptor  ...  F2013  F2014  \
# 0    Environment, Climate Change, Climate Indicator...  ...  1.281  0.456
# 1    Environment, Climate Change, Climate Indicator...  ...  1.333  1.198
# 2    Environment, Climate Change, Climate Indicator...  ...  1.192  1.690
# 3    Environment, Climate Change, Climate Indicator...  ...  0.831  1.946
# 4    Environment, Climate Change, Climate Indicator...  ...  1.044  0.828
# ..                                                 ...  ...    ...    ...
# 151  Environment, Climate Change, Climate Indicator...  ...  0.773  0.686
# 152  Environment, Climate Change, Climate Indicator...  ...  1.114  0.863
# 153  Environment, Climate Change, Climate Indicator...  ...  1.423  1.401
# 154  Environment, Climate Change, Climate Indicator...  ...  0.790  0.917
# 155  Environment, Climate Change, Climate Indicator...  ...  0.118  0.025
#
#      F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 0    1.093  1.555  1.540  1.544  0.910  0.498  1.327  2.012
# 1    1.569  1.464  1.121  2.028  1.675  1.498  1.536  1.518
# 2    1.121  1.757  1.512  1.210  1.115  1.926  2.330  1.688
# 3    1.690  1.990  1.925  1.919  1.964  2.562  1.533  3.243
# 4    1.331  1.609  0.870  1.395  1.752  1.162  1.553  1.212
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 151  0.724  1.267  1.062  0.920  1.379  1.274  1.029  0.951
# 152  1.326  1.615  0.735  2.007  1.204  1.455  1.787  1.074
# 153  1.510  1.732  2.204  0.942  1.477  2.069  1.593  1.970
# 154  1.450  1.401  0.105  0.648  0.855  0.891  0.822  0.686
# 155  0.970  1.270  0.088  0.453  0.925  0.389 -0.125 -0.490
#
# [156 rows x 72 columns]

# %% [markdown]
# ## Etapa 4 - Mineração de dados:
#
# Existem diversas ferramentas no Pandas para obter informações a respeito do DataFrame. Podemos saber a quantidade de linhas e colunas com o método "Shape", os tipos de variaveis de cada coluna com o "Info" e informações Estatísticas com o "Describe"

# %%
# A quantidade de linhas e colunas respectivamente
df.shape
# Out:
# (156, 72)

# %%
# Retorna informações sobre dados numéricos, como a quantidade de valores, a média, o valor mínimo e o máximo
df.describe()
# Out:
#          ObjectId       F1961       F1962       F1963       F1964       F1965  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean   110.647436    0.191115   -0.013436   -0.016237   -0.077577   -0.239186
# std     64.473531    0.427485    0.367600    0.411796    0.329208    0.284645
# min      1.000000   -0.694000   -0.908000   -1.270000   -0.877000   -1.064000
# 25%     57.750000   -0.090500   -0.183250   -0.211000   -0.258000   -0.392500
# 50%    105.500000    0.070500   -0.070500   -0.042000   -0.052000   -0.220500
# 75%    163.250000    0.361250    0.141500    0.236250    0.132500   -0.077750
# max    225.000000    1.892000    0.998000    1.202000    1.097000    0.857000
#
#             F1966       F1967       F1968       F1969  ...       F2013  \
# count  156.000000  156.000000  156.000000  156.000000  ...  156.000000
# mean     0.130468   -0.102654   -0.201904    0.151449  ...    0.889071
# std      0.402946    0.366388    0.288914    0.323968  ...    0.304310
# min     -1.801000   -1.048000   -1.634000   -0.900000  ...    0.118000
# 25%     -0.044500   -0.271750   -0.351000   -0.053000  ...    0.714750
# 50%      0.116000   -0.131500   -0.175000    0.203000  ...    0.863500
# 75%      0.323750    0.032000   -0.066750    0.382250  ...    1.100500
# max      1.151000    1.134000    0.476000    0.832000  ...    1.642000
#
#             F2014       F2015       F2016       F2017       F2018       F2019  \
# count  156.000000  156.000000  156.000000  156.000000  156.000000  156.000000
# mean     1.089949    1.223365    1.401346    1.269795    1.236853    1.385115
# std      0.533827    0.442040    0.382704    0.416590    0.545875    0.417424
# min     -0.092000   -0.430000    0.250000    0.017000    0.238000    0.050000
# 25%      0.773500    1.017750    1.128500    1.021250    0.849500    1.157500
# 50%      0.957500    1.192000    1.406000    1.247500    1.097000    1.378500
# 75%      1.310000    1.454250    1.661500    1.539250    1.500250    1.617750
# max      2.704000    2.613000    2.381000    2.493000    2.524000    2.652000
#
#             F2020       F2021       F2022
# count  156.000000  156.000000  156.000000
# mean     1.481904    1.360699    1.333788
# std      0.525409    0.504987    0.652895
# min      0.229000   -0.425000   -1.305000
# 25%      1.155000    1.017250    0.874750
# 50%      1.425000    1.326000    1.274000
# 75%      1.741500    1.663750    1.749750
# max      3.317000    2.676000    3.243000
#
# [8 rows x 63 columns]

# %%
# Aqui obtemos informações sobre os tipos de valores do DataFrame. o tipo Object é para Strings, e podemos ver que todas as colunas numéricas são Float
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 72 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ObjectId             156 non-null    int64
#  1   Country              156 non-null    object
#  2   ISO2                 156 non-null    object
#  3   ISO3                 156 non-null    object
#  4   Indicator            156 non-null    object
#  5   Unit                 156 non-null    object
#  6   Source               156 non-null    object
#  7   CTS_Code             156 non-null    object
#  8   CTS_Name             156 non-null    object
#  9   CTS_Full_Descriptor  156 non-null    object
#  10  F1961                156 non-null    float64
#  11  F1962                156 non-null    float64
#  12  F1963                156 non-null    float64
#  13  F1964                156 non-null    float64
#  14  F1965                156 non-null    float64
#  15  F1966                156 non-null    float64
#  16  F1967                156 non-null    float64
#  17  F1968                156 non-null    float64
#  18  F1969                156 non-null    float64
#  19  F1970                156 non-null    float64
#  20  F1971                156 non-null    float64
#  21  F1972                156 non-null    float64
#  22  F1973                156 non-null    float64
#  23  F1974                156 non-null    float64
#  24  F1975                156 non-null    float64
#  25  F1976                156 non-null    float64
#  26  F1977                156 non-null    float64
#  27  F1978                156 non-null    float64
#  28  F1979                156 non-null    float64
#  29  F1980                156 non-null    float64
#  30  F1981                156 non-null    float64
#  31  F1982                156 non-null    float64
#  32  F1983                156 non-null    float64
#  33  F1984                156 non-null    float64
#  34  F1985                156 non-null    float64
#  35  F1986                156 non-null    float64
#  36  F1987                156 non-null    float64
#  37  F1988                156 non-null    float64
#  38  F1989                156 non-null    float64
#  39  F1990                156 non-null    float64
#  40  F1991                156 non-null    float64
#  41  F1992                156 non-null    float64
#  42  F1993                156 non-null    float64
#  43  F1994                156 non-null    float64
#  44  F1995                156 non-null    float64
#  45  F1996                156 non-null    float64
#  46  F1997                156 non-null    float64
#  47  F1998                156 non-null    float64
#  48  F1999                156 non-null    float64
#  49  F2000                156 non-null    float64
#  50  F2001                156 non-null    float64
#  51  F2002                156 non-null    float64
#  52  F2003                156 non-null    float64
#  53  F2004                156 non-null    float64
#  54  F2005                156 non-null    float64
#  55  F2006                156 non-null    float64
#  56  F2007                156 non-null    float64
#  57  F2008                156 non-null    float64
#  58  F2009                156 non-null    float64
#  59  F2010                156 non-null    float64
#  60  F2011                156 non-null    float64
#  61  F2012                156 non-null    float64
#  62  F2013                156 non-null    float64
#  63  F2014                156 non-null    float64
#  64  F2015                156 non-null    float64
#  65  F2016                156 non-null    float64
#  66  F2017                156 non-null    float64
#  67  F2018                156 non-null    float64
#  68  F2019                156 non-null    float64
#  69  F2020                156 non-null    float64
#  70  F2021                156 non-null    float64
#  71  F2022                156 non-null    float64
# dtypes: float64(62), int64(1), object(9)
# memory usage: 87.9+ KB

# %%
# Criando uma função para gerar uma coluna com a média dos valores de todas as linhas
def calcular_media_linha(df):
  medias = []
  for i in range(df.shape[0]):
    # Acessa os valores das linhas com valores numéricos
    linha = df.iloc[i, 11:]
    # Calcula a média da linha
    media = linha.mean()

    # Adiciona a média à lista de médias
    medias.append(media)

  return medias

# Calcula a média de cada linha
medias_linhas = calcular_media_linha(df)
# Cria uma coluna chamada 'Média' e adiciona ao dataframe
df['Media'] = medias_linhas

df
# Out:
#      ObjectId                       Country ISO2 ISO3  \
# 0           1  Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                       Albania   AL  ALB
# 2           3                       Algeria   DZ  DZA
# 3           5      Andorra, Principality of   AD  AND
# 4           6                        Angola   AO  AGO
# ..        ...                           ...  ...  ...
# 151       219     Wallis and Futuna Islands   WF  WLF
# 152       220            West Bank and Gaza   PS  PSE
# 153       221                Western Sahara   EH  ESH
# 154       224                        Zambia   ZM  ZMB
# 155       225                      Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 0    Temperature change with respect to a baseline ...  Degree Celsius
# 1    Temperature change with respect to a baseline ...  Degree Celsius
# 2    Temperature change with respect to a baseline ...  Degree Celsius
# 3    Temperature change with respect to a baseline ...  Degree Celsius
# 4    Temperature change with respect to a baseline ...  Degree Celsius
# ..                                                 ...             ...
# 151  Temperature change with respect to a baseline ...  Degree Celsius
# 152  Temperature change with respect to a baseline ...  Degree Celsius
# 153  Temperature change with respect to a baseline ...  Degree Celsius
# 154  Temperature change with respect to a baseline ...  Degree Celsius
# 155  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                                 Source CTS_Code  \
# 0    Food and Agriculture Organization of the Unite...     ECCS
# 1    Food and Agriculture Organization of the Unite...     ECCS
# 2    Food and Agriculture Organization of the Unite...     ECCS
# 3    Food and Agriculture Organization of the Unite...     ECCS
# 4    Food and Agriculture Organization of the Unite...     ECCS
# ..                                                 ...      ...
# 151  Food and Agriculture Organization of the Unite...     ECCS
# 152  Food and Agriculture Organization of the Unite...     ECCS
# 153  Food and Agriculture Organization of the Unite...     ECCS
# 154  Food and Agriculture Organization of the Unite...     ECCS
# 155  Food and Agriculture Organization of the Unite...     ECCS
#
#                        CTS_Name  \
# 0    Surface Temperature Change
# 1    Surface Temperature Change
# 2    Surface Temperature Change
# 3    Surface Temperature Change
# 4    Surface Temperature Change
# ..                          ...
# 151  Surface Temperature Change
# 152  Surface Temperature Change
# 153  Surface Temperature Change
# 154  Surface Temperature Change
# 155  Surface Temperature Change
#
#                                    CTS_Full_Descriptor  ...  F2014  F2015  \
# 0    Environment, Climate Change, Climate Indicator...  ...  0.456  1.093
# 1    Environment, Climate Change, Climate Indicator...  ...  1.198  1.569
# 2    Environment, Climate Change, Climate Indicator...  ...  1.690  1.121
# 3    Environment, Climate Change, Climate Indicator...  ...  1.946  1.690
# 4    Environment, Climate Change, Climate Indicator...  ...  0.828  1.331
# ..                                                 ...  ...    ...    ...
# 151  Environment, Climate Change, Climate Indicator...  ...  0.686  0.724
# 152  Environment, Climate Change, Climate Indicator...  ...  0.863  1.326
# 153  Environment, Climate Change, Climate Indicator...  ...  1.401  1.510
# 154  Environment, Climate Change, Climate Indicator...  ...  0.917  1.450
# 155  Environment, Climate Change, Climate Indicator...  ...  0.025  0.970
#
#      F2016  F2017  F2018  F2019  F2020  F2021  F2022     Media
# 0    1.555  1.540  1.544  0.910  0.498  1.327  2.012  0.494459
# 1    1.464  1.121  2.028  1.675  1.498  1.536  1.518  0.468836
# 2    1.757  1.512  1.210  1.115  1.926  2.330  1.688  0.734066
# 3    1.990  1.925  1.919  1.964  2.562  1.533  3.243  0.793738
# 4    1.609  0.870  1.395  1.752  1.162  1.553  1.212  0.488721
# ..     ...    ...    ...    ...    ...    ...    ...       ...
# 151  1.267  1.062  0.920  1.379  1.274  1.029  0.951  0.350066
# 152  1.615  0.735  2.007  1.204  1.455  1.787  1.074  0.340689
# 153  1.732  2.204  0.942  1.477  2.069  1.593  1.970  0.808393
# 154  1.401  0.105  0.648  0.855  0.891  0.822  0.686  0.406705
# 155  1.270  0.088  0.453  0.925  0.389 -0.125 -0.490  0.202639
#
# [156 rows x 73 columns]

# %% [markdown]
# ## Etapa 5: Interpretação e Avaliação:
#
# Para interpretar os resultados são utilizadas várias técnicas, no caso utilizaremos Dashboards para compreender melhor as informações.

# %%
# Biblioteca para gerar gráficos 2D e 3D
import matplotlib.pyplot as plt

# Filtrando os dados apenas do Brasil
x = df.iloc[26, 11:]

# Gerando um gráfico de linhas com os dados
x.plot()
plt.title('Aumento de temperatura ao longo dos anos no Brasil')
plt.show()

# Printando a média do Brasil
print(f'\nA média de aumento de temperatura é de {x.mean():.2f}° Celsius\n')
# Out:
# A média de aumento de temperatura é de 0.47° Celsius

# %%
# Biblioteca para criar gráficos 2D
import seaborn as sns

# Importando os dados do dataframe
data = df.iloc[0:, 11:]
# gerando um mapa de calor
sns.heatmap(data, yticklabels=False)
# Out:
# <Axes: >

# %%
# Biblioteca para dados geográficos
import geopandas as gpd

# Carregando o mapa-múndi
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Juntando o DataFrame com o mapa-múndi
world = world.merge(df, how='left', left_on='name', right_on='Country')

# Plotando o mapa-múndi
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
world.plot(column='Media', cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
plt.title('Mapa-Múndi por Valor médio de cada país')
plt.axis('off')
plt.show()
# Out:
# <ipython-input-17-c7cc3da9e661>:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
